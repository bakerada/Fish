# %%
import matplotlib.pyplot as plt
from skimage import io
from skimage import transform as tr
from skimage import exposure as ex
import numpy as np
import scipy
# %matplotlib inline

# %%
import numpy as np
from scipy.ndimage import zoom


def clipped_zoom(img, zoom_factor, **kwargs):

    h, w = img.shape[:2]

    # width and height of the zoomed image
    zh = int(np.round(zoom_factor * h))
    zw = int(np.round(zoom_factor * w))

    # for multichannel images we don't want to apply the zoom factor to the RGB
    # dimension, so instead we create a tuple of zoom factors, one per array
    # dimension, with 1's for any trailing dimensions after the width and height.
    zoom_tuple = (zoom_factor,) * 2 + (1,) * (img.ndim - 2)

    # zooming out
    if zoom_factor < 1:
        # bounding box of the clip region within the output array
        top = (h - zh) // 2
        left = (w - zw) // 2
        # zero-padding
        out = np.zeros_like(img)
        out[top:top+zh, left:left+zw] = zoom(img, zoom_tuple, **kwargs)

    # zooming in
    elif zoom_factor > 1:
        # bounding box of the clip region within the input array
        top = (zh - h) // 2
        left = (zw - w) // 2
        out = zoom(img[top:top+zh, left:left+zw], zoom_tuple, **kwargs)
        # `out` might still be slightly larger than `img` due to rounding, so
        # trim off any extra pixels at the edges
        trim_top = ((out.shape[0] - h) // 2)
        trim_left = ((out.shape[1] - w) // 2)
        out = out[trim_top:trim_top+h, trim_left:trim_left+w]

    # if zoom_factor == 1, just return the input array
    else:
        out = img
    return out

# %%
image_data = io.imread('/home/abake116/Fish/test_stg1/img_06332.jpg')
image_data = ex.adjust_gamma(image_data, 0.5)
io.imshow(image_data)

# %%
image_data = io.imread('augmented.jpg')

# %%
io.imshow(image_data)

# %%
image_data = io.imread('augmented.jpg')
image_data = tr.rotate(image_data,180)
io.imshow(image_data)

# %%
image_data = io.imread('augmented.jpg')
image_data = scipy.ndimage.interpolation.zoom(image_data,1.5)
io.imshow(image_data)
# Out:
# /home/abake116/anaconda/envs/tf/lib/python2.7/site-packages/scipy/ndimage/interpolation.py:568: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-749bbf11dc45> in <module>()
#       1 image_data = io.imread('augmented.jpg')
#       2 image_data = scipy.ndimage.interpolation.zoom(image_data,1.5)
# ----> 3 io.imshow(image_data)
#
# /home/abake116/anaconda/envs/tf/lib/python2.7/site-packages/skimage/io/_io.pyc in imshow(arr, plugin, **plugin_args)
#     154     if isinstance(arr, six.string_types):
#     155         arr = call_plugin('imread', arr, plugin=plugin)
# --> 156     return call_plugin('imshow', arr, plugin=plugin, **plugin_args)
# ...
